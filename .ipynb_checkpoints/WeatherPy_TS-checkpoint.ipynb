# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
import time
from scipy.stats import linregress
from pprint import pprint

# Import API key
# from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data_TS/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 616

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# weather map api key 
api_key = "329fb681cf748c24a7ab0c0aabafeeb0"

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?"

query_url = url + "appid=" + api_key + "&q=" + "London"
weather_response = requests.get(query_url).json()
pprint(weather_response)
# Out:
# {'base': 'stations',
#  'clouds': {'all': 31},
#  'cod': 200,
#  'coord': {'lat': 51.51, 'lon': -0.13},
#  'dt': 1584425690,
#  'id': 2643743,
#  'main': {'feels_like': 274.32,
#           'humidity': 81,
#           'pressure': 1027,
#           'temp': 278.16,
#           'temp_max': 280.15,
#           'temp_min': 275.93},
#  'name': 'London',
#  'sys': {'country': 'GB',
#          'id': 1414,
#          'sunrise': 1584425359,
#          'sunset': 1584468497,
#          'type': 1},
#  'timezone': 0,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 230, 'speed': 3.1}}

# %%
# create lists to append the API data into 
name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
long = []
max_temp = []
wind_speed = [] 

counter = 0 

print(f"Beginning Data Retrieval")
print("-------------------------------")

for city in cities: 
    
    try:
        query_url = url + "appid=" + api_key + "&units=imperial" + "&q=" + city
        response = requests.get(query_url).json()
        name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        long.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        
        counter = counter + 1
        
        print(f"Processing Record {counter} of Set | {city}")
              
    except KeyError:
        print("City not found... Skipping it!")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 of Set | yumen
# Processing Record 2 of Set | hilo
# City not found... Skipping it!
# Processing Record 3 of Set | necochea
# City not found... Skipping it!
# City not found... Skipping it!
# Processing Record 4 of Set | rikitea
# Processing Record 5 of Set | rio grande
# Processing Record 6 of Set | mackenzie
# Processing Record 7 of Set | hvide sande
# Processing Record 8 of Set | puerto ayora
# Processing Record 9 of Set | bluff
# City not found... Skipping it!
# Processing Record 10 of Set | chokurdakh
# City not found... Skipping it!
# Processing Record 11 of Set | bucak
# Processing Record 12 of Set | praia
# Processing Record 13 of Set | ponta do sol
# City not found... Skipping it!
# City not found... Skipping it!
# Processing Record 14 of Set | bambous virieux
# Processing Record 15 of Set | barrow
# Processing Record 16 of Set | lebu
# Processing Record 17 of Set | jamestown
# Processing Record 18 of Set | eyemouth
# Processing Record 19 of Set | mataura
# Processing Record 20 of Set | wanning
# Processing Record 21 of Set | new norfolk
# Processing Record 22 of Set | ous
# City not found... Skipping it!
# Processing Record 23 of Set | sergeyevka
# Processing Record 24 of Set | butaritari
# Processing Record 25 of Set | warri
# Processing Record 26 of Set | dikson
# Processing Record 27 of Set | atuona
# Processing Record 28 of Set | faanui
# Processing Record 29 of Set | ushuaia
# Processing Record 30 of Set | calvinia
# Processing Record 31 of Set | cobija
# City not found... Skipping it!
# Processing Record 32 of Set | cayenne
# Processing Record 33 of Set | esil
# Processing Record 34 of Set | kasongo-lunda
# Processing Record 35 of Set | cherskiy
# Processing Record 36 of Set | carnarvon
# Processing Record 37 of Set | saint-philippe
# Processing Record 38 of Set | airai
# Processing Record 39 of Set | kavieng
# Processing Record 40 of Set | riyadh
# Processing Record 41 of Set | huarmey
# Processing Record 42 of Set | kavaratti
# Processing Record 43 of Set | mtwara
# Processing Record 44 of Set | miquelon
# Processing Record 45 of Set | jiuquan
# Processing Record 46 of Set | lompoc
# Processing Record 47 of Set | acurenam
# Processing Record 48 of Set | batemans bay
# Processing Record 49 of Set | mar del plata
# City not found... Skipping it!
# Processing Record 50 of Set | busselton
# Processing Record 51 of Set | puerto colombia
# Processing Record 52 of Set | calbuco
# Processing Record 53 of Set | narsaq
# Processing Record 54 of Set | shepsi
# Processing Record 55 of Set | tabou
# Processing Record 56 of Set | cape town
# City not found... Skipping it!
# Processing Record 57 of Set | gumla
# Processing Record 58 of Set | talnakh
# Processing Record 59 of Set | hobart
# Processing Record 60 of Set | qaanaaq
# Processing Record 61 of Set | rumilly
# Processing Record 62 of Set | vaini
# Processing Record 63 of Set | clyde river
# Processing Record 64 of Set | fairbanks
# Processing Record 65 of Set | soe
# Processing Record 66 of Set | saskylakh
# Processing Record 67 of Set | nisia floresta
# Processing Record 68 of Set | punta arenas
# Processing Record 69 of Set | tirano
# Processing Record 70 of Set | labuhan
# Processing Record 71 of Set | deep river
# Processing Record 72 of Set | kapaa
# City not found... Skipping it!
# Processing Record 73 of Set | bengkulu
# Processing Record 74 of Set | marawi
# Processing Record 75 of Set | luangwa
# Processing Record 76 of Set | yellowknife
# Processing Record 77 of Set | albany
# Processing Record 78 of Set | rio gallegos
# Processing Record 79 of Set | khatanga
# Processing Record 80 of Set | ulaanbaatar
# Processing Record 81 of Set | san patricio
# Processing Record 82 of Set | lavrentiya
# Processing Record 83 of Set | nanortalik
# Processing Record 84 of Set | awbari
# Processing Record 85 of Set | bonavista
# Processing Record 86 of Set | ilulissat
# Processing Record 87 of Set | sayhat
# Processing Record 88 of Set | monrovia
# Processing Record 89 of Set | quesnel
# City not found... Skipping it!
# Processing Record 90 of Set | sebeta
# Processing Record 91 of Set | castro
# Processing Record 92 of Set | avera
# Processing Record 93 of Set | flin flon
# City not found... Skipping it!
# Processing Record 94 of Set | ancud
# Processing Record 95 of Set | port alfred
# City not found... Skipping it!
# Processing Record 96 of Set | paamiut
# Processing Record 97 of Set | lagoa
# Processing Record 98 of Set | batagay
# Processing Record 99 of Set | leh
# Processing Record 100 of Set | tual
# Processing Record 101 of Set | kodiak
# Processing Record 102 of Set | boras
# City not found... Skipping it!
# Processing Record 103 of Set | aklavik
# Processing Record 104 of Set | davidson
# Processing Record 105 of Set | upata
# Processing Record 106 of Set | bethel
# Processing Record 107 of Set | beira
# Processing Record 108 of Set | matinha
# Processing Record 109 of Set | karratha
# City not found... Skipping it!
# Processing Record 110 of Set | saint-avold
# Processing Record 111 of Set | guerrero negro
# City not found... Skipping it!
# Processing Record 112 of Set | anadyr
# Processing Record 113 of Set | vila franca do campo
# Processing Record 114 of Set | avarua
# Processing Record 115 of Set | muisne
# Processing Record 116 of Set | beringovskiy
# City not found... Skipping it!
# Processing Record 117 of Set | csanadpalota
# Processing Record 118 of Set | the valley
# Processing Record 119 of Set | vila do maio
# City not found... Skipping it!
# Processing Record 120 of Set | la rioja
# Processing Record 121 of Set | iqaluit
# Processing Record 122 of Set | sitka
# Processing Record 123 of Set | tiksi
# Processing Record 124 of Set | bismarck
# Processing Record 125 of Set | kununurra
# Processing Record 126 of Set | tongliao
# Processing Record 127 of Set | semypolky
# Processing Record 128 of Set | salinopolis
# Processing Record 129 of Set | mitchell
# Processing Record 130 of Set | bolpur
# Processing Record 131 of Set | srivardhan
# Processing Record 132 of Set | hualmay
# Processing Record 133 of Set | esterhazy
# Processing Record 134 of Set | tuktoyaktuk
# Processing Record 135 of Set | ahipara
# Processing Record 136 of Set | barcelos
# Processing Record 137 of Set | daru
# Processing Record 138 of Set | miri
# Processing Record 139 of Set | rixensart
# City not found... Skipping it!
# Processing Record 140 of Set | soyo
# Processing Record 141 of Set | ribeira grande
# Processing Record 142 of Set | luderitz
# Processing Record 143 of Set | evensk
# City not found... Skipping it!
# Processing Record 144 of Set | lasa
# Processing Record 145 of Set | souillac
# Processing Record 146 of Set | asau
# Processing Record 147 of Set | sao filipe
# Processing Record 148 of Set | arraial do cabo
# Processing Record 149 of Set | saldanha
# Processing Record 150 of Set | mumbwa
# Processing Record 151 of Set | nikolskoye
# City not found... Skipping it!
# Processing Record 152 of Set | shimoda
# Processing Record 153 of Set | malpur
# Processing Record 154 of Set | klaksvik
# Processing Record 155 of Set | saint george
# Processing Record 156 of Set | hachinohe
# Processing Record 157 of Set | hermanus
# Processing Record 158 of Set | lorengau
# Processing Record 159 of Set | hithadhoo
# Processing Record 160 of Set | port macquarie
# Processing Record 161 of Set | berlevag
# Processing Record 162 of Set | nelson bay
# Processing Record 163 of Set | matamoros
# Processing Record 164 of Set | norman wells
# Processing Record 165 of Set | bredasdorp
# Processing Record 166 of Set | provideniya
# Processing Record 167 of Set | kahului
# Processing Record 168 of Set | namibe
# Processing Record 169 of Set | pacific grove
# Processing Record 170 of Set | dingle
# Processing Record 171 of Set | northam
# Processing Record 172 of Set | mehamn
# Processing Record 173 of Set | atar
# Processing Record 174 of Set | pangoa
# Processing Record 175 of Set | chama
# Processing Record 176 of Set | port hardy
# Processing Record 177 of Set | fuyang
# Processing Record 178 of Set | san joaquin
# Processing Record 179 of Set | tukums
# Processing Record 180 of Set | chicama
# Processing Record 181 of Set | nishihara
# Processing Record 182 of Set | fortuna
# Processing Record 183 of Set | kamenica
# Processing Record 184 of Set | itarema
# Processing Record 185 of Set | konstantinovka
# Processing Record 186 of Set | trairi
# Processing Record 187 of Set | longyearbyen
# City not found... Skipping it!
# Processing Record 188 of Set | palmer
# Processing Record 189 of Set | ayorou
# Processing Record 190 of Set | baruun-urt
# Processing Record 191 of Set | lilongwe
# Processing Record 192 of Set | port elizabeth
# Processing Record 193 of Set | gundorovskiy
# Processing Record 194 of Set | georgetown
# Processing Record 195 of Set | redlands
# City not found... Skipping it!
# Processing Record 196 of Set | athens
# Processing Record 197 of Set | asosa
# Processing Record 198 of Set | dunn
# Processing Record 199 of Set | ngunguru
# Processing Record 200 of Set | kijang
# Processing Record 201 of Set | los llanos de aridane
# Processing Record 202 of Set | kargasok
# Processing Record 203 of Set | usinsk
# Processing Record 204 of Set | pimentel
# Processing Record 205 of Set | grindavik
# Processing Record 206 of Set | mapiripan
# Processing Record 207 of Set | los chiles
# Processing Record 208 of Set | yulara
# Processing Record 209 of Set | isangel
# Processing Record 210 of Set | harsud
# Processing Record 211 of Set | frederick
# Processing Record 212 of Set | cidreira
# Processing Record 213 of Set | tasiilaq
# Processing Record 214 of Set | belyy yar
# Processing Record 215 of Set | abu zabad
# Processing Record 216 of Set | marystown
# Processing Record 217 of Set | san quintin
# Processing Record 218 of Set | saint-augustin
# Processing Record 219 of Set | gorlice
# Processing Record 220 of Set | coihaique
# Processing Record 221 of Set | westport
# City not found... Skipping it!
# Processing Record 222 of Set | kulhudhuffushi
# Processing Record 223 of Set | apiai
# Processing Record 224 of Set | camacha
# Processing Record 225 of Set | honningsvag
# Processing Record 226 of Set | luanda
# Processing Record 227 of Set | miyako
# Processing Record 228 of Set | storforshei
# City not found... Skipping it!
# Processing Record 229 of Set | sao raimundo das mangabeiras
# Processing Record 230 of Set | izamal
# Processing Record 231 of Set | caxito
# Processing Record 232 of Set | juba
# Processing Record 233 of Set | likhoslavl
# Processing Record 234 of Set | bayonet point
# Processing Record 235 of Set | snezhnogorsk
# Processing Record 236 of Set | recodo
# Processing Record 237 of Set | pochutla
# Processing Record 238 of Set | bonito
# Processing Record 239 of Set | eldorado
# Processing Record 240 of Set | verkhoyansk
# Processing Record 241 of Set | oistins
# Processing Record 242 of Set | nadym
# Processing Record 243 of Set | waingapu
# Processing Record 244 of Set | east london
# Processing Record 245 of Set | thompson
# Processing Record 246 of Set | troitsko-pechorsk
# Processing Record 247 of Set | porto tolle
# Processing Record 248 of Set | gornyy
# Processing Record 249 of Set | antipovka
# Processing Record 250 of Set | muros
# Processing Record 251 of Set | kaliua
# Processing Record 252 of Set | laguna
# Processing Record 253 of Set | shelekhov
# Processing Record 254 of Set | plettenberg bay
# Processing Record 255 of Set | pato branco
# Processing Record 256 of Set | sorland
# Processing Record 257 of Set | kralendijk
# Processing Record 258 of Set | sosnogorsk
# Processing Record 259 of Set | zhezkazgan
# Processing Record 260 of Set | yerbogachen
# Processing Record 261 of Set | chumikan
# Processing Record 262 of Set | vila velha
# Processing Record 263 of Set | katobu
# Processing Record 264 of Set | agadez
# Processing Record 265 of Set | tefe
# Processing Record 266 of Set | aksu
# Processing Record 267 of Set | upernavik
# Processing Record 268 of Set | la mira
# Processing Record 269 of Set | sobolevo
# Processing Record 270 of Set | loa janan
# Processing Record 271 of Set | carmo do paranaiba
# Processing Record 272 of Set | lata
# Processing Record 273 of Set | san jose de ocoa
# Processing Record 274 of Set | pevek
# Processing Record 275 of Set | tarrafal
# Processing Record 276 of Set | constitucion
# Processing Record 277 of Set | charyshskoye
# Processing Record 278 of Set | bouna
# Processing Record 279 of Set | verkh-usugli
# Processing Record 280 of Set | egvekinot
# City not found... Skipping it!
# Processing Record 281 of Set | esperance
# Processing Record 282 of Set | kedrovyy
# City not found... Skipping it!
# Processing Record 283 of Set | shahdadkot
# Processing Record 284 of Set | kamina
# Processing Record 285 of Set | port-gentil
# Processing Record 286 of Set | bol
# City not found... Skipping it!
# City not found... Skipping it!
# Processing Record 287 of Set | espoo
# Processing Record 288 of Set | merrill
# Processing Record 289 of Set | salo
# Processing Record 290 of Set | surt
# Processing Record 291 of Set | muli
# Processing Record 292 of Set | bilma
# Processing Record 293 of Set | joshimath
# Processing Record 294 of Set | lillers
# Processing Record 295 of Set | popondetta
# Processing Record 296 of Set | pathein
# Processing Record 297 of Set | maroantsetra
# Processing Record 298 of Set | khuzhir
# Processing Record 299 of Set | mmabatho
# Processing Record 300 of Set | sandpoint
# Processing Record 301 of Set | dobson
# Processing Record 302 of Set | mount gambier
# City not found... Skipping it!
# Processing Record 303 of Set | kisanga
# City not found... Skipping it!
# Processing Record 304 of Set | richards bay
# Processing Record 305 of Set | san carlos
# Processing Record 306 of Set | kaitangata
# Processing Record 307 of Set | hanna
# Processing Record 308 of Set | sidi ali
# City not found... Skipping it!
# City not found... Skipping it!
# Processing Record 309 of Set | broken hill
# Processing Record 310 of Set | payson
# Processing Record 311 of Set | soja
# Processing Record 312 of Set | bilibino
# Processing Record 313 of Set | cabo san lucas
# Processing Record 314 of Set | pangkalanbuun
# Processing Record 315 of Set | sabla
# Processing Record 316 of Set | tazovskiy
# Processing Record 317 of Set | mecca
# Processing Record 318 of Set | nador
# Processing Record 319 of Set | khorixas
# Processing Record 320 of Set | yelyzavethradka
# Processing Record 321 of Set | mulki
# Processing Record 322 of Set | port blair
# Processing Record 323 of Set | pozo colorado
# Processing Record 324 of Set | torbay
# Processing Record 325 of Set | nome
# Processing Record 326 of Set | stanghelle
# Processing Record 327 of Set | kaoma
# Processing Record 328 of Set | atasu
# Processing Record 329 of Set | victoria
# Processing Record 330 of Set | hun
# Processing Record 331 of Set | ostersund
# Processing Record 332 of Set | trinidad
# Processing Record 333 of Set | rio branco do sul
# Processing Record 334 of Set | staunton
# Processing Record 335 of Set | ostrovnoy
# Processing Record 336 of Set | nouadhibou
# Processing Record 337 of Set | zbarazh
# Processing Record 338 of Set | ariquemes
# Processing Record 339 of Set | phatthalung
# Processing Record 340 of Set | radhanpur
# Processing Record 341 of Set | hasaki
# Processing Record 342 of Set | yatou
# Processing Record 343 of Set | puro
# Processing Record 344 of Set | rio claro
# Processing Record 345 of Set | santa fe
# Processing Record 346 of Set | bubaque
# City not found... Skipping it!
# Processing Record 347 of Set | turukhansk
# City not found... Skipping it!
# Processing Record 348 of Set | fonte boa
# Processing Record 349 of Set | imeni poliny osipenko
# City not found... Skipping it!
# Processing Record 350 of Set | pisco
# Processing Record 351 of Set | port lincoln
# Processing Record 352 of Set | horsham
# Processing Record 353 of Set | jilib
# Processing Record 354 of Set | calama
# Processing Record 355 of Set | chuy
# Processing Record 356 of Set | rawson
# Processing Record 357 of Set | balkanabat
# Processing Record 358 of Set | kibre mengist
# Processing Record 359 of Set | cairns
# Processing Record 360 of Set | payakumbuh
# Processing Record 361 of Set | severo-kurilsk
# Processing Record 362 of Set | zlobin
# Processing Record 363 of Set | strezhevoy
# Processing Record 364 of Set | fenelon falls
# Processing Record 365 of Set | carman
# Processing Record 366 of Set | dargaville
# City not found... Skipping it!
# Processing Record 367 of Set | ilhabela
# City not found... Skipping it!
# Processing Record 368 of Set | antalaha
# Processing Record 369 of Set | sur
# Processing Record 370 of Set | toumodi
# Processing Record 371 of Set | abaetetuba
# Processing Record 372 of Set | itacoatiara
# Processing Record 373 of Set | talaya
# Processing Record 374 of Set | tuy hoa
# Processing Record 375 of Set | praia da vitoria
# Processing Record 376 of Set | clinton
# Processing Record 377 of Set | pedasi
# Processing Record 378 of Set | mayahi
# Processing Record 379 of Set | half moon bay
# Processing Record 380 of Set | luganville
# Processing Record 381 of Set | bay saint louis
# Processing Record 382 of Set | tura
# Processing Record 383 of Set | ahuimanu
# Processing Record 384 of Set | aborlan
# Processing Record 385 of Set | najran
# Processing Record 386 of Set | katsuura
# City not found... Skipping it!
# Processing Record 387 of Set | gdov
# Processing Record 388 of Set | grand gaube
# Processing Record 389 of Set | kibuye
# Processing Record 390 of Set | karnobat
# Processing Record 391 of Set | college
# City not found... Skipping it!
# Processing Record 392 of Set | larsnes
# Processing Record 393 of Set | gat
# Processing Record 394 of Set | ferme-neuve
# Processing Record 395 of Set | cabedelo
# Processing Record 396 of Set | manggar
# Processing Record 397 of Set | korem
# Processing Record 398 of Set | sao joao da barra
# City not found... Skipping it!
# Processing Record 399 of Set | portland
# Processing Record 400 of Set | nizwa
# Processing Record 401 of Set | yanam
# Processing Record 402 of Set | forestville
# Processing Record 403 of Set | tiznit
# Processing Record 404 of Set | garowe
# Processing Record 405 of Set | creel
# Processing Record 406 of Set | elbistan
# Processing Record 407 of Set | sabang
# Processing Record 408 of Set | piopio
# City not found... Skipping it!
# Processing Record 409 of Set | zhigansk
# Processing Record 410 of Set | channel-port aux basques
# Processing Record 411 of Set | oranjemund
# Processing Record 412 of Set | walvis bay
# Processing Record 413 of Set | boralday
# City not found... Skipping it!
# Processing Record 414 of Set | bathsheba
# Processing Record 415 of Set | caravelas
# Processing Record 416 of Set | gimli
# Processing Record 417 of Set | mandalgovi
# Processing Record 418 of Set | chunhuhub
# Processing Record 419 of Set | margate
# Processing Record 420 of Set | flinders
# Processing Record 421 of Set | tomatlan
# Processing Record 422 of Set | faya
# Processing Record 423 of Set | ambilobe
# Processing Record 424 of Set | abalak
# Processing Record 425 of Set | maragheh
# Processing Record 426 of Set | palimbang
# Processing Record 427 of Set | kem
# Processing Record 428 of Set | lodwar
# Processing Record 429 of Set | ondjiva
# Processing Record 430 of Set | hamilton
# Processing Record 431 of Set | vao
# City not found... Skipping it!
# Processing Record 432 of Set | ak-dovurak
# Processing Record 433 of Set | boa vista
# Processing Record 434 of Set | dubbo
# Processing Record 435 of Set | tuatapere
# Processing Record 436 of Set | aureliana
# Processing Record 437 of Set | comodoro rivadavia
# Processing Record 438 of Set | igrim
# Processing Record 439 of Set | starkville
# Processing Record 440 of Set | jijiga
# Processing Record 441 of Set | nemuro
# Processing Record 442 of Set | ortigueira
# Processing Record 443 of Set | codrington
# Processing Record 444 of Set | high rock
# Processing Record 445 of Set | mahebourg
# Processing Record 446 of Set | rocha
# Processing Record 447 of Set | conceicao do araguaia
# City not found... Skipping it!
# Processing Record 448 of Set | hunchun
# Processing Record 449 of Set | majene
# Processing Record 450 of Set | burns lake
# Processing Record 451 of Set | asyut
# Processing Record 452 of Set | rognan
# Processing Record 453 of Set | ventspils
# Processing Record 454 of Set | tijuana
# Processing Record 455 of Set | xuddur
# Processing Record 456 of Set | le port
# Processing Record 457 of Set | karlskrona
# Processing Record 458 of Set | atlantic city
# Processing Record 459 of Set | adrar
# Processing Record 460 of Set | sarangani
# Processing Record 461 of Set | watsa
# Processing Record 462 of Set | hovd
# Processing Record 463 of Set | general roca
# Processing Record 464 of Set | kiruna
# Processing Record 465 of Set | olimpia
# Processing Record 466 of Set | taoudenni
# City not found... Skipping it!
# Processing Record 467 of Set | viedma
# Processing Record 468 of Set | la ronge
# Processing Record 469 of Set | moundou
# Processing Record 470 of Set | dunedin
# Processing Record 471 of Set | aykhal
# Processing Record 472 of Set | biltine
# City not found... Skipping it!
# Processing Record 473 of Set | phan thiet
# Processing Record 474 of Set | jiwani
# Processing Record 475 of Set | havre-saint-pierre
# Processing Record 476 of Set | olafsvik
# Processing Record 477 of Set | nova granada
# Processing Record 478 of Set | rabaul
# Processing Record 479 of Set | matara
# Processing Record 480 of Set | varnavino
# Processing Record 481 of Set | nikolayevskaya
# Processing Record 482 of Set | abrau-dyurso
# Processing Record 483 of Set | gazojak
# Processing Record 484 of Set | moerai
# Processing Record 485 of Set | pointe michel
# City not found... Skipping it!
# Processing Record 486 of Set | chapleau
# Processing Record 487 of Set | gamba
# Processing Record 488 of Set | xai-xai
# Processing Record 489 of Set | lima
# City not found... Skipping it!
# Processing Record 490 of Set | inirida
# City not found... Skipping it!
# Processing Record 491 of Set | hervey bay
# Processing Record 492 of Set | beloha
# City not found... Skipping it!
# Processing Record 493 of Set | belaya gora
# Processing Record 494 of Set | cockburn town
# Processing Record 495 of Set | gwanda
# Processing Record 496 of Set | pontianak
# Processing Record 497 of Set | zhuhai
# Processing Record 498 of Set | pangai
# City not found... Skipping it!
# Processing Record 499 of Set | ilheus
# City not found... Skipping it!
# Processing Record 500 of Set | vostok
# Processing Record 501 of Set | buala
# Processing Record 502 of Set | rorvik
# City not found... Skipping it!
# Processing Record 503 of Set | yarmouth
# Processing Record 504 of Set | kota tinggi
# Processing Record 505 of Set | nuuk
# Processing Record 506 of Set | chapais
# Processing Record 507 of Set | englewood
# Processing Record 508 of Set | uray
# Processing Record 509 of Set | vizinga
# Processing Record 510 of Set | mastic beach
# Processing Record 511 of Set | leningradskiy
# Processing Record 512 of Set | makakilo city
# Processing Record 513 of Set | san matias
# Processing Record 514 of Set | ekibastuz
# Processing Record 515 of Set | kudahuvadhoo
# Processing Record 516 of Set | lisakovsk
# Processing Record 517 of Set | dawson creek
# Processing Record 518 of Set | sambava
# Processing Record 519 of Set | xining
# Processing Record 520 of Set | trapani
# Processing Record 521 of Set | naze
# Processing Record 522 of Set | twin falls
# Processing Record 523 of Set | aswan
# Processing Record 524 of Set | baiyin
# Processing Record 525 of Set | skhodnya
# City not found... Skipping it!
# Processing Record 526 of Set | mindelo
# Processing Record 527 of Set | medea
# Processing Record 528 of Set | semporna
# Processing Record 529 of Set | mayo
# Processing Record 530 of Set | misratah
# Processing Record 531 of Set | ghogha
# Processing Record 532 of Set | alcazar de san juan
# Processing Record 533 of Set | alice springs
# Processing Record 534 of Set | gambela
# Processing Record 535 of Set | hay river
# Processing Record 536 of Set | merritt island
# Processing Record 537 of Set | tupa
# Processing Record 538 of Set | kozluk
# Processing Record 539 of Set | yelizovo
# Processing Record 540 of Set | la seyne-sur-mer
# Processing Record 541 of Set | port hedland
# Processing Record 542 of Set | banjar
# Processing Record 543 of Set | picota
# Processing Record 544 of Set | nioro
# Processing Record 545 of Set | sao geraldo do araguaia
# Processing Record 546 of Set | awjilah
# Processing Record 547 of Set | candoni
# Processing Record 548 of Set | kamariotissa
# City not found... Skipping it!
# Processing Record 549 of Set | ambon
# Processing Record 550 of Set | coxim
# Processing Record 551 of Set | manokwari
# Processing Record 552 of Set | vestmanna
# Processing Record 553 of Set | honiara
# Processing Record 554 of Set | hailar
# Processing Record 555 of Set | galle
# Processing Record 556 of Set | chimbote
# Processing Record 557 of Set | ust-nera
# Processing Record 558 of Set | khani

# %% [markdown]
# # Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df = pd.DataFrame({
    "City": name,
    "Cloudiness":cloudiness, 
    "Country":country,
    "Date":date, 
    "Humidity": humidity,
    "Lat":lat, 
    "Long":long, 
    "Max Temp": max_temp,
    "Wind Speed":wind_speed
})
weather_df.count()

# save data to CSV 
weather_df.to_csv("exported_weather_df.csv")

# display data frame
weather_df.head()
# Out:
#          City  Cloudiness Country        Date  Humidity    Lat    Long  \
# 0       Yumen           0      CN  1584426305         9  40.28   97.20
# 1        Hilo          90      US  1584426306        78  19.73 -155.09
# 2    Necochea          28      AR  1584425745        94 -38.55  -58.74
# 3     Rikitea          61      PF  1584426307        84 -23.12 -134.97
# 4  Rio Grande           0      BR  1584425769        97 -32.03  -52.10
#
#    Max Temp  Wind Speed
# 0     54.84       25.95
# 1     73.99        5.82
# 2     57.99        4.00
# 3     80.40        9.53
# 4     61.00        8.59

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Max Temp"], edgecolors="black", facecolors="red")
plt.title(f"City Latitude vs. Max Temp")
plt.xlabel("Lat")
plt.ylabel("Max Temp")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Humidity"], edgecolors="black", facecolors="skyblue")
plt.title(f"City Latitude vs. Humidity")
plt.xlabel("Lat")
plt.ylabel("Max Temp")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Cloudiness"], edgecolors="black", facecolors="green")
plt.title(f"City Latitude vs. Cloudiness")
plt.xlabel("Lat")
plt.ylabel("Max Temp")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Wind Speed"], edgecolors="black", facecolors="magenta")
plt.title(f"City Latitude vs. Wind Speed")
plt.xlabel("Lat")
plt.ylabel("Max Temp")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: -0.8151657406810827

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.760263355051646

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.10358336015746494

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.14689473425583055

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: -0.08733547918934018

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.21881426893991618

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.1071382774388479

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: -0.322483077139538
